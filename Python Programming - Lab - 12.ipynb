# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 12</b></center>
# <center><b><h3>Roll No : 412</b></center>
# <center><b><h3>Name : Narola Yash N.</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    a = int(input("Enter the first value:"))
    b = int(input("Enter the second value:"))
    print("Your numbers is " + str(a) + ', ' + str(b))
    print(a // b)
except ZeroDivisionError as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# Enter the first value: 1
# Enter the second value: 0
# Your numbers is 1, 0
# Error type: <class 'ZeroDivisionError'>
# Error message: integer division or modulo by zero

# %%
try:
    a = int(input("Enter the first value:"))
    b = int(input("Enter the second value:"))
    print("Your numbers is " + str(a) + ', ' + b)
    print(a // b)
except TypeError as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# Enter the first value: 1
# Enter the second value: 3
# Error type: <class 'TypeError'>
# Error message: can only concatenate str (not "int") to str

# %%
try:
    a = int(input("Enter the first value:"))
    b = int(input("Enter the second value:"))
    print("Your numbers is " + str(a) + ', ' + str(b))
    print(a // b)
except ValueError as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# Enter the first value: 12
# Enter the second value: abc
# Error type: <class 'ValueError'>
# Error message: invalid literal for int() with base 10: 'abc'

# %%
try:
    a = int(input("Enter the first value:"))
    b = int(input("Enter the second value:"))
    print("Your numbers is " + str(a) + ', ' + str(b))
    print(a // b)
except Exception as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# Enter the first value: 1
# Enter the second value: 0
# Your numbers is 1, 0
# Error type: <class 'ZeroDivisionError'>
# Error message: integer division or modulo by zero

# %%
try:
    a = int(input("Enter the first value:"))
    b = int(input("Enter the second value:"))
    print("Your numbers is " + str(a) + ', ' + str(b))
    print(a // b)
except Exception as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# Enter the first value: 1
# Enter the second value: a
# Error type: <class 'ValueError'>
# Error message: invalid literal for int() with base 10: 'a'

# %%
try:
    a = int(input("Enter the first value:"))
    b = int(input("Enter the second value:"))
    print("Your numbers is " + str(a) + ', ' + b)
    print(a // b)
except Exception as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# Enter the first value: 1
# Enter the second value: 2
# Error type: <class 'TypeError'>
# Error message: can only concatenate str (not "int") to str

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
listt = [1, 2, 3, 4, 5]
print(listt[1])
print(listt[10])
# Out:
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 listt = [1, 2, 3, 4, 5]
#       2 print(listt[1])
# ----> 3 print(listt[10])
#
# IndexError: list index out of range

# %%
try:
    listt = [1, 2, 3, 4, 5]
    print(listt[1])
    print(listt[10])
except IndexError as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# 2
# Error type: <class 'IndexError'>
# Error message: list index out of range

# %%
dicct = {1: "One", 2: "Two"}
print(dicct[1])
print(dicct[3])
# Out:
# One
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 3
#       1 dicct = {1: "One", 2: "Two"}
#       2 print(dicct[1])
# ----> 3 print(dicct[3])
#
# KeyError: 3

# %%
try:
    dicct = {1: "One", 2: "Two"}
    print(dicct[1])
    print(dicct[3])
except KeyError as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# One
# Error type: <class 'KeyError'>
# Error message: 3

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
fp = open("xyx.txt", "r")
fp.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 fp = open("xyx.txt", "r")
#       2 fp.read()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xyx.txt'

# %%
try:
    fp = open("xyx.txt", "r")
    fp.read()
except FileNotFoundError as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# Error type: <class 'FileNotFoundError'>
# Error message: [Errno 2] No such file or directory: 'xyx.txt'

# %%
import xyz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 import xyz
#
# ModuleNotFoundError: No module named 'xyz'

# %%
try:
    import xyz
except ModuleNotFoundError as err:
    print("Error type:", type(err))
    print("Error message:", err)
# Out:
# Error type: <class 'ModuleNotFoundError'>
# Error message: No module named 'xyz'

# %% [markdown]
# ### 04) WAP that handles all type of exceptions in a single except block in standard error message format.

# %%
try:
    a = int(input("Enter the first value:"))
    b = int(input("Enter the second value:"))
    print("Your numbers is " + str(a) + ', ' + b)
    # print("Your numbers is " + str(a) + ', ' + str(b))
    print(a // b)

    # listt = [1, 2, 3, 4, 5]
    # print(listt[1])
    # print(listt[10])

    # dicct = {1: "One", 2: "Two"}
    # print(dicct[1])
    # print(dicct[3])

    # fp = open("xyx.txt", "r")
    # fp.read()

    # import xyz
except Exception as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
# Out:
# Enter the first value: 1
# Enter the second value: 2
# Error type: <class 'TypeError'>
# Error message: can only concatenate str (not "int") to str

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try:
    age = int(input("Enter your age:"))
    if age <= 0:
        raise ValueError("Age can not be less then or equal zero")
except Exception as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
else:
    print("Your age is", age)
finally:
    print("Exit")
# Out:
# Enter your age: 18
# Your age is 18
# Exit

# %%
try:
    age = int(input("Enter your age:"))
    if age <= 0:
        raise ValueError("Age can not be less then or equal zero")
except Exception as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
else:
    print("Your age is", age)
finally:
    print("Exit")
# Out:
# Enter your age: 0
# Error type: <class 'ValueError'>
# Error message: Age can not be less then or equal zero
# Exit

# %% [markdown]
# ### 06) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def divide():
    try:
        a = int(input("Enter the first value:"))
        b = int(input("Enter the second value:"))
        result = a // b
    except ZeroDivisionError as exce:
        print("Error type:", type(exce))
        print("Error message:", exce)
    else:
        return result

d = divide()
print("xyz", d)
# Out:
# Enter the first value: 12
# Enter the second value: 0
# Error type: <class 'ZeroDivisionError'>
# Error message: integer division or modulo by zero
# xyz None

# %% [markdown]
# ### 07) WAP to accept item prices and calculate total. Raise ValueError if price is negative, otherwise print the total bill amount.

# %%
def billing(item, price):
    try:
        if price < 0:
            raise ValueError("Price can not be negative")
    except ValueError as exce:
        print("Error type:", type(exce))
        print("Error message:", exce)
    else:
        bill = item * price
        print(bill)
    finally:
        print("Thank You For Visiting!")

# billing(10, 10)
billing(10, -10)
# Out:
# Error type: <class 'ValueError'>
# Error message: Price can not be negative
# Thank You For Visiting!

# %% [markdown]
# ### 08) Create a short program that prompts the user for a list of grades separated by commas.
# #### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# #### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
try:
    grede = [int(i) for i in input("Enter the gredes separated by commas").split(", ")]
except Exception as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
else:
    print(grede)
# Out:
# Enter the gredes separated by commas a
# Error type: <class 'ValueError'>
# Error message: invalid literal for int() with base 10: 'a'

# %% [markdown]
# ### 09) Accept 5 subject marks (0-100). Use assert for validation.
#
# #### Sample Input (Error Case)
# #####  Enter marks: 110
#
# #### Sample Output (Error Case)
# ##### AssertionError: Marks should be between 0 and 100.
#
# #### Sample Input (Normal Case)
# ##### Valid marks entered
#
# #### Sample Output (Normal Case)
# ##### Average Marks displayed

# %%
try:
    marks = []
    for i in range(5):
        markInOne = int(input("Enter the marks:"))
        assert 0 <= markInOne <= 100, 'Marks should be between 0 to 100'
        marks.append(markInOne)
except Exception as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
else:
    print("Valid marks entered")
    print("Average marks:", sum(marks) / len(marks))
finally:
    print("Exit")
# Out:
# Enter the marks: 400
# Error type: <class 'AssertionError'>
# Error message: Marks should be between 0 to 100
# Exit

# %%
try:
    marks = []
    for i in range(5):
        markInOne = int(input("Enter the marks:"))
        assert 0 <= markInOne <= 100, 'Marks should be between 0 to 100'
        marks.append(markInOne)
except Exception as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
else:
    print("Valid marks entered")
    print("Average marks:", sum(marks) / len(marks))
finally:
    print("Exit")
# Out:
# Enter the marks: 98
# Enter the marks: 95
# Enter the marks: 67
# Enter the marks: 85
# Enter the marks: 7
# Valid marks entered
# Average marks: 70.4
# Exit

# %% [markdown]
# ### 10) WAP that gets password from user. Password must have at least 8 characters and one digit.
# ### Raise WeakPasswordError if invalid, print the messsage "Correct" otherwise.

# %%
class WeakPasswordError(Exception):
    pass

try:
    password = input("Enter your password:")
    if len(password) < 8 or not any(i.isdigit() for i in password):
        raise WeakPasswordError("Password is not valid")
except Exception as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
else:
    print("Correct")
finally:
    print("Exit")
# Out:
# Enter your password: ajghdlashdg
# Error type: <class '__main__.WeakPasswordError'>
# Error message: Password is not valid
# Exit

# %% [markdown]
# ### 11) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
class NegativeNumberError(Exception):
    pass

try:
    num = int(input("Enter the number:"))
    if num < 0:
        raise NegativeNumberError("Cannot calculate the square roor of a negative number")
except NegativeNumberError as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
else:
    print(num ** (1 / 2))
finally:
    print("Exit")
# Out:
# Enter the number: 25
# 5.0
# Exit

# %%
class NegativeNumberError(Exception):
    pass

try:
    num = int(input("Enter the number:"))
    if num < 0:
        raise NegativeNumberError("Cannot calculate the square roor of a negative number")
except NegativeNumberError as exce:
    print("Error type:", type(exce))
    print("Error message:", exce)
else:
    print(num ** (1 / 2))
finally:
    print("Exit")
# Out:
# Enter the number: -25
# Error type: <class '__main__.NegativeNumberError'>
# Error message: Cannot calculate the square roor of a negative number
# Exit
