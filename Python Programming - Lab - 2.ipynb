# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 2</b></center>
# <center><b><h3>Roll No.: 412</b></center>
# <center><b><h3>Name: Narola Yash N.</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("Hello World..!!")
# Out:
# Hello World..!!

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
# print(object(S), sep=" ", end="\n", file="Sys.stdout", flash=False)

name = input("Enter your name:")
print("Hello "+name+", welcome to Python Lab.")
print("Hello ", name, ", Welcome to Python Lab.", sep="")
print(id(name))
print(type(name))

# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str
# print("Yash" + str(18))  Ok...
# print("Yash", 18)  ok...
# Out:
# Enter your name: Yash
# Hello Yash, welcome to Python Lab.
# Hello Yash, Welcome to Python Lab.
# 1729641430208
# <class 'str'>

# %%
import sys

# %%
name = ""
size = sys.getsizeof(name)
print(size)

name = "Yash"
size = sys.getsizeof(name)
print(size)
# Out:
# 41
# 45

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
num1, num2, num3 = input("Enter three numbers(With space):").split(); # split a string from space
print(num1, num2, num3)
num1 = int(num1)
num2 = int(num2)
num3 = int(num3)
print("Sum: ", num1+num2+num3)
avg = (num1+num2+num3) / 3
print("Average: ", avg)
# Out:
# Enter three numbers(With space): 45 55 89
# 45 55 89
# Sum:  189
# Average:  63.0

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
name, age, pr = input("Enter your name, age and pr (comma seprated):").split(",")
age = int(age)
pr = float(pr)

print(name, "Type:", type(name))
print(age, "Type:", type(age))
print(pr, "Type:", type(pr))
# print(f"Name: {name}: {type(name)}")
# print(f"Age: {age}: {type(age)}")
# print(f"Percentage: {pr}: {type(pr)}")
# Out:
# Enter your name, age and pr (comma seprated): Yash, 18, 55.5
# Yash Type: <class 'str'>
# 18 Type: <class 'int'>
# 55.5 Type: <class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("Python", "Programming", "Basics", sep=" | ", end="###")
# Out:
# Python | Programming | Basics###

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
str = input("Enter the string:")
print("Value:", str)
print("Type:", type(str))
print("ID:",id(str))
# Out:
# Enter the string: hello
# Value: hello
# Type: <class 'str'>
# ID: 2199603386032

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
a = 10
print("Original ID of a:", id(a))
a = 20
print("New ID of a:", id(a))
# Out:
# Original ID of a: 140710266320072
# New ID of a: 140710266320392

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print("""Welcome to Python
This is the second lab
Enjoy coding!""")
# Out:
# Welcome to Python
# This is the second lab
# Enjoy coding!

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(f"{'Yash':5} end")     # in f-string string variable ni alignment by default laft hase
print(f"{3525.486:10} end")  # and number ni default alignment Right hase
print(f"{10: 5}")
print(f"{10 + 50j: 20}")
print()

print(f"{'Sr No':^5} {'Name':^12} {'Subject':^8} {'Grade':^5} {'Percentage':^10}")
print(f"{1:>5} {'Nisha Patel':<12} {'Math':<8} {'A':^5} {92:>10}")
print(f"{2:>5} {'Aarav Modi':<12} {'Science':<8} {'B+':^5} {85:>10}")
print(f"{3:>5} {'Jiya Shah':<12} {'English':<8} {'A+':^5} {96:>10}")
# Out:
# Yash  end
#   3525.486 end
#    10
#            ( 10+50j)
#
# Sr No     Name     Subject  Grade Percentage
#     1 Nisha Patel  Math       A           92
#     2 Aarav Modi   Science   B+           85
#     3 Jiya Shah    English   A+           96

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
num = float(input("Input:"))
print(f"2 decimals: {num:.2f}")
print(f"3 decimals: {num:.3f}")
print(f"Width 10: {num:<10}")
# Out:
# Input: 37.2567
# 2 decimals: 37.26
# 3 decimals: 37.257
# Width: 37.2567

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
a, b = input("Enter two number:").split();
a = int(a)
b = int(b)

print(f"Sum = {a+b}")
print(f"Difference = {a-b}")
print(f"Product = {a-b}")

# print("Sum =", a+b)
# print("Difference =", a-b)
# print("Product =", a*b)
# Out:
# Enter two number: 12 8
# Sum = 20
# Difference = 4
# Product = 4

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
dd, mm, yyyy = input("Enter the date (space seprated):").split();
print(dd, mm, yyyy, sep="/")
print(yyyy, mm, dd, sep="-")
# Out:
# Enter the date (space seprated): 10 12 2025
# 10/12/2025
# 2025-12-10

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
radius = float(input("Enter radius of the circle: "))

area = 3.14 * radius * radius
per = 2 * 3.14 * radius

print("Area of the circle:", area)
print("Perimeter (Circumference) of the circle:", per)
# Out:
# Enter radius of the circle:  10
# Area of the circle: 314.0
# Perimeter (Circumference) of the circle: 62.800000000000004

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
c = float(input("Enter the Cesius:"))
f = (c*9/5) + 32
print("Fahrenheit:", f)

f = float(input("Enter the Fahrenheit:"))
c = (f-32) * (5/9)
print("Fahrenheit:", c)
# Out:
# Enter the Cesius: 0
# Fahrenheit: 32.0
# Enter the Fahrenheit: 32
# Fahrenheit: 0.0

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
kilo = float(input("Enter the distance in kilometer:"))
meter = kilo * 1000
feet = kilo * 3280.84
inch = kilo * 39,370.1
cm = kilo * 100000

print("Kilometer =", kilo)
print("meter =", meter)
print("feet =", feet)
print("inches =", inch)
print("centimeter =", cm)
# Out:
# Enter the distance in kilometer: 1
# Kilometer = 1.0
# meter = 1000.0
# feet = 3280.84
# inches = 39370.1
# centimeter = 100000.0

# %%
print(locals())
print()
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'name = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello", name, "Welcome to Python Lab.")', 'name = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello", name, ", Welcome to Python Lab.")', 'name = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", spe="")', 'name = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\nprint("Yash" + 18)', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\nprint("Yash", str(18))', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  ', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\nprint("Yash" + str(18))  ', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  Ok...', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  Ok...\nprint("Yash", 18)', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\nprint(id(name))\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  Ok...\n# print("Yash", 18)  ok...', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\nprint(id(name))\nprint(type(name))\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  Ok...\n# print("Yash", 18)  ok...', 'name, age, pr = input("Enter your name, age and pr (comma seprated):").split(",")\nage = int(age)\npr = float(pr)\n\nprint(Name, "Type:", type(name))\n# print(f"Name: {name}: {type(name)}")\n# print(f"Age: {age}: {type(age)}")\n# print(f"Percentage: {pr}: {type(pr)}")', 'name, age, pr = input("Enter your name, age and pr (comma seprated):").split(",")\nage = int(age)\npr = float(pr)\n\nprint(Name, "Type:", type(name))\n# print(f"Name: {name}: {type(name)}")\n# print(f"Age: {age}: {type(age)}")\n# p ...
#
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'name = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello", name, "Welcome to Python Lab.")', 'name = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello", name, ", Welcome to Python Lab.")', 'name = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", spe="")', 'name = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\nprint("Yash" + 18)', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\nprint("Yash", str(18))', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  ', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\nprint("Yash" + str(18))  ', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  Ok...', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  Ok...\nprint("Yash", 18)', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\nprint(id(name))\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  Ok...\n# print("Yash", 18)  ok...', '# print(object(S), sep=" ", end="\\n", file="Sys.stdout", flash=False)\n\nname = input("Enter your name:")\nprint("Hello "+name+", welcome to Python Lab.")\nprint("Hello ", name, ", Welcome to Python Lab.", sep="")\nprint(id(name))\nprint(type(name))\n\n# print("Yash" + 18)  TypeError: can only concatenate str (not "int") to str\n# print("Yash" + str(18))  Ok...\n# print("Yash", 18)  ok...', 'name, age, pr = input("Enter your name, age and pr (comma seprated):").split(",")\nage = int(age)\npr = float(pr)\n\nprint(Name, "Type:", type(name))\n# print(f"Name: {name}: {type(name)}")\n# print(f"Age: {age}: {type(age)}")\n# print(f"Percentage: {pr}: {type(pr)}")', 'name, age, pr = input("Enter your name, age and pr (comma seprated):").split(",")\nage = int(age)\npr = float(pr)\n\nprint(Name, "Type:", type(name))\n# print(f"Name: {name}: {type(name)}")\n# print(f"Age: {age}: {type(age)}")\n# p ...

# %%
num = 1_234_567  # store number in readalbe form use underscore 
print(num)
print(type(num))
# Out:
# 1234567
# <class 'int'>

# %%
# Complex numbers
a = 45
b = 10
cNum = complex(a, b)
print(cNum)

cNum = 21+10J
print(cNum)

print("Real part", cNum.real)
print("Imaginary part", cNum.imag)

print(type(cNum))
# Out:
# (45+10j)
# (21+10j)
# Real part 21.0
# Imaginary part 10.0
# <class 'complex'>

# %%
# Boolean 
bool = True
print(bool, type(bool))

bool = False
print(bool, type(bool))
# Out:
# True <class 'bool'>
# False <class 'bool'>

# %%
import keyword
print(keyword.kwlist)

print(type(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# <class 'list'>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  n
# Nothing done.
