# %% [markdown]
# ### Magic Commands

# %%
# %ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is DCB1-5F8D
#
#  Directory of D:\Yash\Darshan University\Semester_4\Python
#
# 11-03-2026  09:59    <DIR>          .
# 01-03-2026  16:11    <DIR>          ..
# 08-01-2026  18:14                51 .gitignore
# 11-03-2026  09:59    <DIR>          .ipynb_checkpoints
# 25-02-2026  21:34    <DIR>          .virtual_documents
# 25-02-2026  22:14    <DIR>          Extra Labs
# 11-02-2026  10:11               155 Hello.txt
# 04-02-2026  10:43               160 Hello_2.txt
# 04-02-2026  10:54                15 marks.txt
# 08-03-2026  12:26    <DIR>          Material
# 04-02-2026  10:19                76 new.txt
# 04-02-2026  11:14               322 newHello.txt
# 11-02-2026  10:39                38 numbers.txt
# 11-02-2026  11:28               990 output.txt
# 04-02-2026  11:11               471 primenumber.txt
# 26-11-2025  11:04             1,082 Python Programming - Lab - 1.ipynb
# ...

# %%
# %pwd
# Out:
# 'D:\\Yash\\Darshan University\\Semester_4\\Python'

# %%
# %cd ..
# Out:
# D:\Yash\Darshan University\Semester_4

# %%
# %pwd
# Out:
# 'D:\\Yash\\Darshan University\\Semester_4'

# %%
a, b = 3, 4
t = a + b
print(t)

# %%
# %who

# %%
# %whos

# %%
# %reset

# %%
# %who

# %%
# %history

# %%
# %history -n 3

# %%
# %time list_ = [i for i in range(1000000)]

# %%
# %%writefile test.py

list_ = [i for i in range(10000)]
a,b = 3, 4
t = a + b
print(t)

Overwriting test.py
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %%
# %run test.py

# %%
# %load test.py

# %%
# %timeit a = 0    (multi time exe krse)
