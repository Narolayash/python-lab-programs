# %%
card_num = input("Enter the card number")
cn = "**** " * 3 + card_num[-4:]
print(cn)
# Out:
# Enter the card number 1234 4567 1234 4567
# **** **** **** 4567

# %%
list_tuple = [(1, 2, 3), (4, 8, 12)]
k = 4

for tp in list_tuple:
